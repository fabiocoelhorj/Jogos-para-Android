# %% [markdown]
# # Analisando os jogos para celular no sistema Android

# %% [markdown]
# ### Importando os dados

# %%
import pandas as pd

# %%
df = pd.read_csv('C:/Users/Suporte/Documents/Python_Projects/csv/android-games.csv')

# %% [markdown]
# ### Verificando os Dados da Tabela

# %%
df.head(4)
# Out:
#    rank                         title  total ratings installs  average rating  \
# 0     1  Garena Free Fire - The Cobra       80678661  500.0 M            4.33
# 1     2   PUBG MOBILE: Graffiti Prank       35971961  100.0 M            4.24
# 2     3     Mobile Legends: Bang Bang       25836869  100.0 M            4.08
# 3     4                   Brawl Stars       17181659  100.0 M            4.27
#
#    growth (30 days)  growth (60 days)  price     category  5 star ratings  \
# 0               2.9               7.9    0.0  GAME ACTION        61935712
# 1               2.0               3.1    0.0  GAME ACTION        26670566
# 2               1.6               3.3    0.0  GAME ACTION        17850942
# 3               4.1               6.6    0.0  GAME ACTION        12493668
#
#    4 star ratings  3 star ratings  2 star ratings  1 star ratings   paid
# 0         4478738         2795172         1814999         9654037  False
# ...

# %% [markdown]
# ### Quantas Linhas e Colunas possui

# %%
df.shape
# Out:
# (1730, 15)

# %% [markdown]
# ### Os 5 Maiores Jogos 5 Estrelas

# %%
df.nlargest(5, '5 star ratings')
# Out:
#       rank                         title  total ratings  installs  \
# 0        1  Garena Free Fire - The Cobra       80678661   500.0 M
# 1424     1                Clash of Clans       55170976   500.0 M
# 200      1                Subway Surfers       35305263  1000.0 M
# 1        2   PUBG MOBILE: Graffiti Prank       35971961   100.0 M
# 622      1              Candy Crush Saga       30859251  1000.0 M
#
#       average rating  growth (30 days)  growth (60 days)  price  \
# 0               4.33               2.9               7.9    0.0
# 1424            4.49               0.3               0.6    0.0
# 200             4.44               0.5               1.1    0.0
# 1               4.24               2.0               3.1    0.0
# 622             4.56               0.7               1.6    0.0
#
#            category  5 star ratings  4 star ratings  3 star ratings  \
# 0       GAME ACTION        61935712         4478738         2795172
# ...

# %% [markdown]
# ### Os jogos Mais Instalados

# %%
 df[['title', 'installs']].groupby('installs').max()
# Out:
#                                       title
# installs
# 1.0 M                        회색도시 for Kakao
# 10.0 M    🚓🚦Car Driving School Simulator 🚕🚸
# 100.0 M                          slither.io
# 100.0 k                         فكر ـ Think
# 1000.0 M                     Subway Surfers
# 5.0 M                피망 뉴맞고 : 고스톱으로 대한민국 1등
# 50.0 M                   eFootball PES 2021
# 500.0 M                        Temple Run 2
# 500.0 k                超級單字王 - 英檢、多益、托福 輕鬆學

# %% [markdown]
# ### Alterando nome das Colunas 'Title' e '4 star ratings'

# %%
df.rename(columns = {'title' : 'Título', '5 star ratings' : '5 Estrelas'}, inplace = True)

# %%
df.head(1)
# Out:
#    rank                        Título  total ratings installs  average rating  \
# 0     1  Garena Free Fire - The Cobra       80678661  500.0 M            4.33
#
#    growth (30 days)  growth (60 days)  price     category  5 Estrelas  \
# 0               2.9               7.9    0.0  GAME ACTION    61935712
#
#    4 star ratings  3 star ratings  2 star ratings  1 star ratings   paid
# 0         4478738         2795172         1814999         9654037  False

# %% [markdown]
# ### Mostrando Somente a Coluna com os 8 primeiros Títulos'

# %%
 print(df['Título'][0:8])
# Out:
# 0                    Garena Free Fire - The Cobra
# 1                     PUBG MOBILE: Graffiti Prank
# 2                       Mobile Legends: Bang Bang
# 3                                     Brawl Stars
# 4    Sniper 3D: Fun Free Online FPS Shooting Game
# 5                                  Shadow Fight 2
# 6        Call of Duty®: Mobile - Day of Reckoning
# 7                                        Among Us
# Name: Título, dtype: object

# %% [markdown]
# ### Os 5 Jogos Menos Avaliados ('total ratings')

# %%
df.nsmallest(5, 'total ratings')
# Out:
#      rank                           Título  total ratings installs  \
# 923   100  Beat Blader 3D: Dash and Slash!          38238   10.0 M
# 922    99                       Pink Piano          38740   10.0 M
# 921    98                    Project: Muse          40251    1.0 M
# 920    97         Anime Tiles: Piano Music          40374    1.0 M
# 919    96        Viet Piano Tiles New 2020          40385    1.0 M
#
#      average rating  growth (30 days)  growth (60 days)  price    category  \
# 923            4.00               7.8              15.7    0.0  GAME MUSIC
# 922            4.00               2.2               5.8    0.0  GAME MUSIC
# 921            4.22               1.2               2.8    0.0  GAME MUSIC
# 920            3.91               3.4               8.6    0.0  GAME MUSIC
# 919            4.49               0.9               3.0    0.0  GAME MUSIC
#
#      5 Estrelas  4 star ratings  3 star ratings  2 star ratings  \
# ...

# %% [markdown]
# ### Filtrando os Jogos Pagos (paid = True)

# %%
df.loc[df['paid']==True]
# Out:
#       rank                 Título  total ratings installs  average rating  \
# 91      92          Hitman Sniper         848831   10.0 M            4.41
# 153     54               Terraria         317546    1.0 M            4.65
# 211     12              Minecraft        3999232   10.0 M            4.54
# 261     62          Geometry Dash         767518    1.0 M            4.62
# 477     64                 Reigns         146504  500.0 k            4.58
# 869     46               Cytus II         109687    1.0 M            4.59
# 1588    65  Trivia Crack (No Ads)          74594  500.0 k            4.58
#
#       growth (30 days)  growth (60 days)  price        category  5 Estrelas  \
# 91                 0.3               0.8   0.99     GAME ACTION      607502
# 153                1.0               2.3   4.99  GAME ADVENTURE      264563
# 211                1.4               2.8   7.49     GAME ARCADE     3214765
# ...

# %% [markdown]
# ### Jogos acima de $ 2.00

# %%
df.loc[df['price'] >= 2]
# Out:
#      rank     Título  total ratings installs  average rating  \
# 153    54   Terraria         317546    1.0 M            4.65
# 211    12  Minecraft        3999232   10.0 M            4.54
# 477    64     Reigns         146504  500.0 k            4.58
#
#      growth (30 days)  growth (60 days)  price        category  5 Estrelas  \
# 153               1.0               2.3   4.99  GAME ADVENTURE      264563
# 211               1.4               2.8   7.49     GAME ARCADE     3214765
# 477               0.1               0.2   2.99       GAME CARD      108627
#
#      4 star ratings  3 star ratings  2 star ratings  1 star ratings  paid
# 153           24837           10184            4387           13572  True
# 211          312995          138682           70661          262126  True
# 477           25330            5696            2743            4105  True

# %% [markdown]
# ### Apagando a Coluna "1 Star Ratings"

# %%
del df['1 star ratings']

# %%
df.head(1)
# Out:
#    rank                        Título  total ratings installs  average rating  \
# 0     1  Garena Free Fire - The Cobra       80678661  500.0 M            4.33
#
#    growth (30 days)  growth (60 days)  price     category  5 Estrelas  \
# 0               2.9               7.9    0.0  GAME ACTION    61935712
#
#    4 star ratings  3 star ratings  2 star ratings   paid
# 0         4478738         2795172         1814999  False

# %% [markdown]
# ### Alterando a Coluna "2 Star Ratings" de Inteiro para Float (sem inplace)

# %%
star2 = df['2 star ratings'].astype(float)

# %%
star2.head(5)
# Out:
# 0    1814999.0
# 1     893674.0
# 2     725429.0
# 3     383478.0
# 4     375159.0
# Name: 2 star ratings, dtype: float64

# %% [markdown]
# ### Média de Preço dos Aplicativos

# %%
 df['price'].mean()
# Out:
# 0.012965317919075145

# %% [markdown]
# ### Média de Classificação (0 a 5)

# %%
df['average rating'].mean()
# Out:
# 4.313410404624285
